# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.load("train_log_uresnet.npy")

# %%
a
# Out:
# array([[ 4.62937336,  9.92338568],
#        [ 4.93648663,  9.88420134],
#        [ 4.8704435 , 16.08225244],
#        [ 4.8554619 , 10.01034581],
#        [ 4.89039029,  9.92165693],
#        [ 4.866346  , 14.47739926],
#        [ 4.88449999, 10.05873184],
#        [ 4.84094251, 10.16327822],
#        [ 4.85690849, 14.18869402],
#        [ 4.89614352, 10.07803037],
#        [ 4.86054673, 10.07248516],
#        [ 4.87195109, 10.18596343],
#        [ 4.8521586 , 10.07352672],
#        [ 4.96433273,  7.1433804 ],
#        [ 4.91180038,  7.24372414],
#        [ 4.92544282,  6.68728007],
#        [ 4.91569074,  6.69785772],
#        [ 4.91496029,  7.46577424],
#        [ 4.91679497,  6.69246641],
#        [ 4.9303186 ,  6.89211131],
#        [ 4.91024221,  7.64005687],
#        [ 4.91484365,  6.8054278 ],
#        [ 4.92940197,  6.68974842],
#        [ 4.92164947,  6.71613067],
#        [ 4.90341391,  6.70057804],
#        [ 4.92408822,  6.69726858],
#        [ 4.93702607,  6.7291941 ],
# ...

# %%
plt.plot([i[0] for i in a])

# %%
plt.plot([i[1] for i in a])
